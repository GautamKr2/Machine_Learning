# %% [markdown]
# # Handling-Date-Time

# %% [markdown]
# ### Loading the dataset

# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('E:/Dataset/orders.csv')
time = pd.read_csv('E:/Dataset/messages.csv')

# %%
date.head(3)
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1

# %%
time.head(3)
# Out:
#                   date                                               msg
# 0  2013-12-15 00:50:00                          ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00  ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00          Днепр.м 43 позн.с д/ж *.о  067.16.34.576

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# ### Working with Date

# %%
date['date'] = pd.to_datetime(date['date'])

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %% [markdown]
# #### Extract year

# %%
date['date_year'] = date['date'].dt.year

# %% [markdown]
# #### Extract month

# %%
date['date_month_no'] = date['date'].dt.month

# %%
date['date_month_name'] = date['date'].dt.month_name()

# %% [markdown]
# #### Extract day

# %%
date['date_day'] = date['date'].dt.day

# %%
date['date_dow'] = date['date'].dt.dayofweek

# %%
date['date_dow_name'] = date['date'].dt.day_name()

# %%
date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday', 'Monday']), 1, 0)

# %%
date.sample(2)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no  \
# 551 2019-06-27        6756       17       2       2019              6
# 225 2019-04-26        1503       21      12       2019              4
#
#     date_month_name  date_day  date_dow date_dow_name  date_is_weekend
# 551            June        27         3      Thursday                0
# 225           April        26         4        Friday                0

# %% [markdown]
# #### Extract week of the year

# %%
date['date_week'] = date['date'].dt.isocalendar().week

# %% [markdown]
# #### Extract quarter of the year

# %%
date['date_quarter'] = date['date'].dt.quarter

# %% [markdown]
# #### Extract time elapsed between two dates

# %%
import datetime
today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2026, 4, 27, 0, 19, 57, 124211)

# %%
today - date['date']
# Out:
# 0     2330 days 00:19:57.124211
# 1     2812 days 00:19:57.124211
# 2     2743 days 00:19:57.124211
# 3     2445 days 00:19:57.124211
# 4     2668 days 00:19:57.124211
#                  ...
# 995   2758 days 00:19:57.124211
# 996   2699 days 00:19:57.124211
# 997   2547 days 00:19:57.124211
# 998   2612 days 00:19:57.124211
# 999   2386 days 00:19:57.124211
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today-date['date']).dt.days
# Out:
# 0      2330
# 1      2812
# 2      2743
# 3      2445
# 4      2668
#        ...
# 995    2758
# 996    2699
# 997    2547
# 998    2612
# 999    2386
# Name: date, Length: 1000, dtype: int64

# %%
# Passed week are
np.round((today-date['date'])/np.timedelta64(1,'W'),0)
# Out:
# 0      333.0
# 1      402.0
# 2      392.0
# 3      349.0
# 4      381.0
#        ...
# 995    394.0
# 996    386.0
# 997    364.0
# 998    373.0
# 999    341.0
# Name: date, Length: 1000, dtype: float64

# %% [markdown]
# ### Working with time

# %%
time.sample(2)
# Out:
#                     date                                                msg
# 677  2013-05-21 00:27:00  красивая дама скучает одна в квартире!Кто на ч...
# 192  2012-07-11 00:15:00  М 29 ЛЕТ ИЩЕТ ДЕВУШКУ ДЛЯ РЕАЛЬНЫХ И ПРИЯТНЫХ ...

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
time['date'] = pd.to_datetime(time['date'])

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 15.8+ KB

# %% [markdown]
# #### Extract hour, minute, and second

# %%
time['hour'] = time['date'].dt.hour
time['minute'] = time['date'].dt.minute
time['second'] = time['date'].dt.second

# %%
time.sample(2)
# Out:
#                    date                                                msg  \
# 312 2012-01-19 23:41:00  М 40. Познк. с жен. из Днепро-вска  с/о. 063-7...
# 644 2012-03-11 01:23:00  ПАРЕНЬ ПОЗНАКОМИТЬСЯ С ДЕВУШКОЙ. МНЕ 21.809978...
#
#      hour  minute  second
# 312    23      41       0
# 644     1      23       0

# %% [markdown]
# #### Extract time, and date

# %%
time['time_time'] = time['date'].dt.time

# %%
time['time_date'] = time['date'].dt.date

# %%
time.sample()
# Out:
#                    date                                                msg  \
# 944 2015-05-21 23:11:00  П 27/184/90 ищу дев 18-30 лет для с/с совм про...
#
#      hour  minute  second time_time   time_date
# 944    23      11       0  23:11:00  2015-05-21

# %% [markdown]
# #### Finding time difference

# %%
today-time['date']
# Out:
# 0     4515 days 23:29:57.124211
# 1     4380 days 00:39:57.124211
# 2     4865 days 23:58:57.124211
# 3     4167 days 23:48:57.124211
# 4     4565 days 01:08:57.124211
#                  ...
# 995   5154 days 23:29:57.124211
# 996   4476 days 01:05:57.124211
# 997   4941 days 00:42:57.124211
# 998   5057 days 00:45:57.124211
# 999   4329 days 00:54:57.124211
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
(today-time['date'])/np.timedelta64(1,'h')
# Out:
# 0      108383.499201
# 1      105120.665868
# 2      116783.982535
# 3      100031.815868
# 4      109561.149201
#            ...
# 995    123719.499201
# 996    107425.099201
# 997    118584.715868
# 998    121368.765868
# 999    103896.915868
# Name: date, Length: 1000, dtype: float64
